# %%
import matplotlib.pyplot as plt
from IPython.display import display
import numpy as np
import pandas as pd
import math
import csv
import seaborn as sns

# %%
def atttribute_values(d):
    unsorted_values = []
    with open(d.filename, 'r', newline='') as file:
        reader = csv.reader(file)
        next(reader)#skip labels
        for row in reader:
            unsorted_values.append(row)
            
    return np.transpose(np.array(unsorted_values))

# %%
def find_attributes(d):
    with open(d.filename, 'r', newline='') as file:
        reader = csv.reader(file)
        return (next(reader))

# %%
def get_raw_data(d):
    unsorted_values = []   
    with open(d.filename, 'r', newline='') as file:
        reader = csv.reader(file)
        next(reader)#skip labels
        for row in reader:
            unsorted_values.append(row)
            
    return unsorted_values

# %%
# sorts a 2d array by some column, using merge sort (smallest to largest)
def merge_sort_2d(array, index):######ONLY USE FOR INTEGERS OR DOUBLES########NO STRINGS########

    if len(array) == 1:
        return array
    
    
    split_location = len(array)//2
    
    half1 = merge_sort_2d(array[:split_location], index)
    half2 = merge_sort_2d(array[split_location:], index)
    
    merged_list = []
    
    counter1 = 0
    counter2 = 0
    
    for i in range(len(array)):
        if(counter1 < len(half1) and counter2 < len(half2)):
            if(half1[counter1][index] < half2[counter2][index]):
                merged_list.append(half1[counter1])
                counter1+=1
            else:
                merged_list.append(half2[counter2])
                counter2+=1
        else:
            break
            
    while(counter1 < len(half1)):#one of these will not be true
        merged_list.append(half1[counter1])
        counter1+=1
    while(counter2 < len(half2)):
        merged_list.append(half2[counter2])
        counter2+=1
        
        
    return merged_list

# %%
class Dataset():
    def __init__(self, filename):
        self.filename = f"{filename}.csv"
        self.attributes = find_attributes(self)
        self.number_of_attributes = len(self.attributes)
        self.attribute_values = atttribute_values(self)
        self.raw = get_raw_data(self)
        
    def get_attributes():
        return self.attributes
    
    def sort_by_raw(self,index):#return a dataset object sorted by some specific attribute
        return merge_sort_2d(self.raw,index)
        
    def update_attribute_values(self, new_d):#ex: after sorted by some index
        self.attribute_values = new_d

# %%
class ScatterPlot:
    def __init__(self, x_vals, y_vals, figsize=(8, 6), title="KNN model visual", xlabel="X", ylabel="Y", grid=True):
        self.figsize = figsize
        self.title = title
        self.xlabel = xlabel
        self.ylabel = ylabel
        self.grid = grid
        self.data_points = [xvals,yvals]  
        self.x_vals = x_vals
        self.yvals = yvals
    
    def display(self):
        # Create the plot
        plt.figure(figsize=self.figsize)
        plt.plot(x_vals, y_vals, 'o')
        plt.title(self.title)
        plt.xlabel(self.xlabel)
        plt.ylabel(self.ylabel)
        plt.grid(self.grid)
        plt.show()

# %%
class KNN_Object():
    def __init__ (self, d):
        self.graph = Scatterplot(d.attribute_values[0],
                                 d.attribute_values[1],
                                 "KNN model(2d)", 
                                 d.attributes[0], 
                                 d.attributes[1])#the graph will only display the first two attributes in the list
                   #can also serve as an example of how high dimensional data doesn't calssify well using this algorithm
    def display(self):
        self.graph.display()
    
    
    """def add_value_and_classify(self, values):
        self.x_data.append(values[0])
        self.y_data.append(values[1])
        self.scatter.set_offsets(list(zip(self.x_data, self.y_data))) """

# %%
iris_dataset = Dataset("iris")

sorted_by_length = iris_dataset.sort_by_raw(0)
sorted_by_length = np.transpose(sorted_by_length)
iris_dataset.update_attribute_values(sorted_by_length)

graph = KNN_Object(iris_dataset)
graph.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 7
#       4 sorted_by_length = np.transpose(sorted_by_length)
#       5 iris_dataset.update_attribute_values(sorted_by_length)
# ----> 7 graph = KNN_Object(iris_dataset)
#       8 graph.display()
#
# Cell In[60], line 3, in KNN_Object.__init__(self, d)
#       2 def __init__ (self, d):
# ----> 3     self.graph = Scatterplot(d.attribute_values[0],
#       4                              d.attribute_values[1],
#       5                              "KNN model(2d)",
#       6                              d.attributes[0],
#       7                              d.attributes[1])
#
# Cell In[59], line 12, in Scatterplot.__init__(self, x_data, y_data, title, x_label, y_label, figsize)
#       9 self.plot = (x_data, y_data, 'o')
#      11 # Set labels and title
# ---> 12 self.fig.xlabel(x_label)
#      13 self.fig.ylabel(y_label)
#      14 self.fig.title(title)
#
# AttributeError: 'Figure' object has no attribute 'xlabel'
